# %%
# Import the modules.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1.
#Load the dataset
Melbourne_Housing_Data=pd.read_csv('C:\\Users\\Dell\\Downloads\\melb_data_1647253563.csv')
print('Melbourne Housing Data:',Melbourne_Housing_Data)
Melbourne_Housing_Data.head()
# Out:
# Melbourne Housing Data:               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
for c in Melbourne_Housing_Data:
    print(c)
# Out:
# Suburb
# Address
# Rooms
# Type
# Price
# Method
# SellerG
# Date
# Distance
# Postcode
# Bedroom2
# Bathroom
# Car
# Landsize
# BuildingArea
# YearBuilt
# CouncilArea
# Lattitude
# Longtitude
# Regionname
# Propertycount

# %%
Melbourne_Housing_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#2.
plt.figure(figsize=(20,6))
sns.boxplot(Melbourne_Housing_Data['Car'])
plt.show()

# %%
#3.
plt.figure(figsize=(20,6))
sns.boxplot(x='Type', y='Price', data=Melbourne_Housing_Data)
plt.show()

# %%
plt.figure(figsize=(21,7))
sns.countplot(x='Rooms', data=Melbourne_Housing_Data)
plt.grid()

# %%
#4.
max_rooms=Melbourne_Housing_Data['Rooms'].max()
print('Maximum value of a room:',max_rooms)
# Out:
# Maximum value of a room: 10

# %%
#5.
plt.figure(figsize=(20,6))
sns.boxplot(data=Melbourne_Housing_Data)
plt.show()

# %%
#6.
from scipy.stats import skew
Melbourne_Housing_Data_float=Melbourne_Housing_Data.select_dtypes(["int64","float64"])
for c in Melbourne_Housing_Data_float:
    print(c)
    print(skew(Melbourne_Housing_Data_float[c]))
    
    plt.figure()
    sns.displot(Melbourne_Housing_Data_float[c],kind='kde')
    plt.show()
# Out:
# Rooms
# 0.3764364470400018
# Price
# 2.2393769237559704
# Distance
# 1.6767518487767612
# Postcode
# 4.07570196391326
# Bedroom2
# 0.7739967055545368
# Bathroom
# 1.37725382352233
# Car
# nan
# Landsize
# 95.2268805331916
# BuildingArea
# nan
# YearBuilt
# nan
# Lattitude
# -0.42664780159815474
# Longtitude
# -0.21096758939777033
# Propertycount
# 1.0692212294124601

# %%
#7.
data4=Melbourne_Housing_Data['Distance'].max()
data4
# Out:
# 48.1

# %%
Melbourne_Housing_Data['Distance_category'] = ' '
Melbourne_Housing_Data.loc[(Melbourne_Housing_Data['Distance'] > 0) & (Melbourne_Housing_Data['Distance'] <= 16), 'Distance_category'] = 'Near'
Melbourne_Housing_Data.loc[(Melbourne_Housing_Data['Distance'] > 16) & (Melbourne_Housing_Data['Distance'] <= 36), 'Distance_category'] = 'Far'
Melbourne_Housing_Data.loc[(Melbourne_Housing_Data['Distance'] > 36) & (Melbourne_Housing_Data['Distance'] <= 49), 'Distance_category'] = 'Very Far'
Melbourne_Housing_Data.head(30)
# Out:
#         Suburb              Address  Rooms Type      Price Method   SellerG  \
# 0   Abbotsford         85 Turner St      2    h  1480000.0      S    Biggin
# 1   Abbotsford      25 Bloomburg St      2    h  1035000.0      S    Biggin
# 2   Abbotsford         5 Charles St      3    h  1465000.0     SP    Biggin
# 3   Abbotsford     40 Federation La      3    h   850000.0     PI    Biggin
# 4   Abbotsford          55a Park St      4    h  1600000.0     VB    Nelson
# 5   Abbotsford       129 Charles St      2    h   941000.0      S    Jellis
# 6   Abbotsford         124 Yarra St      3    h  1876000.0      S    Nelson
# 7   Abbotsford        98 Charles St      2    h  1636000.0      S    Nelson
# 8   Abbotsford   6/241 Nicholson St      1    u   300000.0      S    Biggin
# 9   Abbotsford        10 Valiant St      2    h  1097000.0      S    Biggin
# 10  Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB    Jellis
# ...

# %%
#8.
plt.figure(figsize=(20,6))
sns.boxplot(x='Regionname', y='Price', data=Melbourne_Housing_Data)
plt.show()

# %%
#9.
print("Correlation of price with other variables")
sns.heatmap(Melbourne_Housing_Data_float.corr(),annot=True,linewidth=0.1)
plt.show()
# Out:
# Correlation of price with other variables

# %%
#10.
plt.figure(figsize=(12,5), dpi=96)
sns.regplot(x='Landsize', y='Rooms', data=df, color='blue')
plt.xlabel('Temperature')
plt.ylabel('Relative Humidity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8344/1655135851.py in <module>
#       1 #10.
# ----> 2 sns.displot(x='Landsize',y='Rooms',data=Melbourne_Housing_Data_float,kind='reg')
#       3 plt.show()
#
# ~\anaconda3\Phython\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2199     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2200
# -> 2201     _check_argument("kind", ["hist", "kde", "ecdf"], kind)
#    2202
#    2203     # --- Initialize the FacetGrid object
#
# ~\anaconda3\Phython\lib\site-packages\seaborn\utils.py in _check_argument(param, options, value)
#     783     """Raise if value for param is not in options."""
# ...

# %%
plt.figure(figsize=(12,5), dpi=96)
sns.regplot(x='B', y='R', data=Melbourne_Housing_Data, color='blue')
plt.xlabel('BuildingArea')
plt.ylabel('Rooms')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\Phython\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\Phython\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\Phython\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.figure(figsize=(12,5), dpi=96)
sns.regplot(x='T', y='RH', data=df, color='blue')
plt.xlabel('Temperature')
plt.ylabel('Relative Humidity')
plt.show()

# %%
#11.
data2=Melbourne_Housing_Data['SellerG'].value_counts()
data3=data2.head(3)
print("Top Three sellers:\n",data3)
# Out:
# Top Three sellers:
#  Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Name: SellerG, dtype: int64

# %%
#13.
max_price=Melbourne_Housing_Data['Price'].max()
max_price
# Out:
# 9000000.0

# %%
Melbourne_Housing_Data['Price_category'] = ' '
Melbourne_Housing_Data.loc[(Melbourne_Housing_Data['Price'] > 84000) & (Melbourne_Housing_Data['Price'] <= 1000000), 'Price_category'] = 'Non Expensive'
Melbourne_Housing_Data.loc[(Melbourne_Housing_Data['Price'] > 1000000) & (Melbourne_Housing_Data['Price'] <= 5000000), 'Price_category'] = 'Moderate'
Melbourne_Housing_Data.loc[(Melbourne_Housing_Data['Price'] > 5000000) & (Melbourne_Housing_Data['Price'] <= 9000000), 'Price_category'] = 'Expensive'
Melbourne_Housing_Data.head(30)
# Out:
#         Suburb              Address  Rooms Type      Price Method   SellerG  \
# 0   Abbotsford         85 Turner St      2    h  1480000.0      S    Biggin
# 1   Abbotsford      25 Bloomburg St      2    h  1035000.0      S    Biggin
# 2   Abbotsford         5 Charles St      3    h  1465000.0     SP    Biggin
# 3   Abbotsford     40 Federation La      3    h   850000.0     PI    Biggin
# 4   Abbotsford          55a Park St      4    h  1600000.0     VB    Nelson
# 5   Abbotsford       129 Charles St      2    h   941000.0      S    Jellis
# 6   Abbotsford         124 Yarra St      3    h  1876000.0      S    Nelson
# 7   Abbotsford        98 Charles St      2    h  1636000.0      S    Nelson
# 8   Abbotsford   6/241 Nicholson St      1    u   300000.0      S    Biggin
# 9   Abbotsford        10 Valiant St      2    h  1097000.0      S    Biggin
# 10  Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB    Jellis
# ...

# %%
plt.figure(figsize=(21,7))
sns.countplot(x='Price_category', data=Melbourne_Housing_Data)
plt.grid()
